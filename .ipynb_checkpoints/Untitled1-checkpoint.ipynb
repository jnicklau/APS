# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm 
import scipy.stats as stats
import numpy as np

# %%
def qqplot(y1):
    print(y[0:10])
    sm.qqplot(np.sort(y), fit = True,line ='45') 
    plt.show()

# %%
nsample = 10
rng = np.random.default_rng()

# %%
x = stats.t.rvs(3, size=nsample, random_state=rng)
y = stats.t.rvs(3, size=nsample, random_state=rng)

print(x)
print(y)
# Out:
# [ 0.18239875  0.20595535  2.18113854 -1.7642023  -2.43382887  1.80461183
#  -0.26068078  0.68460486  2.67926281  0.06720047]
# [0.43044186 0.12657153 0.20868672 1.06412945 2.10743039 0.37910594
#  1.10660347 0.14685842 0.02833455 2.77717348]

# %%
qqplot(x)
# Out:
# [0.43044186 0.12657153 0.20868672 1.06412945 2.10743039 0.37910594
#  1.10660347 0.14685842 0.02833455 2.77717348]
